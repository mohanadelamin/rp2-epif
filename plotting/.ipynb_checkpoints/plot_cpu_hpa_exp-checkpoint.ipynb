# %%
# %%javascript
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return false;
# }

# %%
import matplotlib.pyplot as plt
import os
import pandas as pd
from datetime import datetime
import numpy as np

# %%
# Get data
# os.system("./get_data.sh")

# %%
def get_time_in_s(x):
    x = x.split("T")[-1]
    x = datetime.strptime(x, '%H:%M:%S.%f')
    a_timedelta = x - datetime(1900, 1, 1)
    seconds = a_timedelta.total_seconds()
    return seconds

def get_time_date(x):
    x = x.split("T")[-1]
    x = datetime.strptime(x, '%H:%M:%S.%f')
    return x

def locust_get_time_in_s(x):
    a_timedelta = x - datetime(1900, 1, 1)
    seconds = a_timedelta.total_seconds()
    
    return seconds 

def locust_get_time(x):
    return datetime.strptime(x, "%H:%M:%S")

def plot_request_per_second(df_locust):
    plt.title("Requests per second")
    plt.plot(df_locust["Time_in_s"], df_locust["values"], label="rps")
#     plt.plot(df_locust["Time_in_s"], df_locust["fails"], label="fails")
    plt.xlabel("s")
    plt.ylabel("rps")
    plt.xticks(rotation=30)
    plt.legend()
    plt.show()

def plot_users_per_second(df_locust):
    plt.title("users per second")
    plt.plot(df_locust["Time_in_s"], df_locust["users"], label="users")
    plt.xlabel("s")
    plt.ylabel("users")
    plt.xticks(rotation=30)
    plt.legend()
    plt.show()    
    

    
def plot_response_times_per_second(df_locust):
    plt.title("Response time per second")
    plt.plot(df_locust["Time_in_s"], df_locust["response_time_95"], label="response_time_95")
    plt.plot(df_locust["Time_in_s"], df_locust["response_time_50"], label="response_time_50")
    plt.xlabel("s")
    plt.ylabel("response_time")
    plt.xticks(rotation=30)
    plt.legend()
    plt.show()   
    
def plot_memory(df):
    plt.plot(df["Time_in_s"], df["Memory"])
    plt.xlabel("s")
    plt.xticks(rotation=30)
    plt.ylabel("Memory")
    plt.show()

def plot_cpu_per_pod(df, pod, color="b"):
    plt.title(f"CPU usage pod {pod}")
        
    # Plot the cpu at a gradient of 1 precent, get microseconds of CPU per s (milicore)
    plt.plot(df["Time_in_s"], np.gradient(df["CPU"]), label=f"cpu {pod}", color=color)

#     if "proxy" in pod:
#         # Plot bf cpu request and limit
#         plt.axhline(int(PROXY_LIMITS_CPU.replace("m", "")), color="r", label=f"CPU limit {pod}")
#         plt.axhline(int(PROXY_REQUEST_CPU.replace("m", "")), color="g", label=f"CPU request{pod}")
        
#     if "server" in pod:
#         # Plot bf cpu request and limit
#         plt.axhline(int(SERVER_LIMITS_CPU.replace("m", "")), color="r", label=f"CPU limit {pod}")
#         plt.axhline(int(SERVER_REQUEST_CPU.replace("m", "")), color="g", label=f"CPU request{pod}") 
        
#     if "epi-bf" in pod:
#         # Plot bf cpu request and limit
#         plt.axhline(int(BF_LIMITS_CPU.replace("m", "")), color="r", label=f"CPU limit {pod}")
#         plt.axhline(int(BF_REQUEST_CPU.replace("m", "")), color="g", label=f"CPU request{pod}")

#     if "locust" in pod:
#         # Plot bf cpu request and limit
#         plt.axhline(int(CLIENT_LIMITS_CPU.replace("m", "")), color="r", label=f"locust CPU limit {pod}")
#         plt.axhline(int(CLIENT_REQUEST_CPU.replace("m", "")), color="g", label=f"locust request {pod}")


    plt.xlabel("s")
    plt.ylabel("CPU (milicore)")
    plt.xticks(rotation=30)
    plt.legend()
        
        
main_data_dir="../hpa_test_data"

for d_name in os.listdir(main_data_dir):
    print("Directory:", d_name)
#     if d_name != "TEST_NO_4_20210618200735":
#         continue
        
    data_directory = f"{main_data_dir}/{d_name}"
    print(f"data directory: {data_directory}")
    
    # Get locust data
    locust_csv = f"{data_directory}/locust_data.csv"
    df_locust = pd.read_csv(locust_csv)
    df_locust['time'] = df_locust['time'].apply(lambda x: locust_get_time(x))
    df_locust["Time_in_s"] = df_locust["time"].apply(lambda x: locust_get_time_in_s(x))
    # Start point to make everything start at zero seconds
    start_point = df_locust["Time_in_s"][0] 
    df_locust["Time_in_s"] = df_locust["Time_in_s"] -  start_point  


    # Get bf milicore data
    with open(f"{data_directory}/bf_milicore.txt") as f:
        for i, x in enumerate(f.readlines()):
            if i == 0:
                BF_LIMITS_CPU, BF_REQUEST_CPU, BF_LIMITS_MEM, BF_REQUEST_MEM = x.split(",")
            if i == 1:
                SERVER_LIMITS_CPU, SERVER_REQUEST_CPU, SERVER_LIMITS_MEM, SERVER_REQUEST_MEM = x.split(",")
            if i == 2:
                PROXY_LIMITS_CPU, PROXY_REQUEST_CPU, PROXY_LIMITS_MEM, PROXY_REQUEST_MEM = x.split(",")
            if i == 3:
                CLIENT_LIMITS_CPU, CLIENT_REQUEST_CPU, CLIENT_LIMITS_MEM, CLIENT_REQUEST_MEM = x.split(",")

    colors = ["r", "g", "b", "orange", "yellow", "brown"]

    # Plot EPI
    for pod in os.listdir(data_directory):
        if not pod.startswith("epi-bf"):
            continue
        print(pod)
        f_name = f"{data_directory}/" + pod
        print("f_name: ", f_name)
        
        df = pd.read_csv(f_name, delimiter=",")
        df = df.iloc[5:]
        df = df.reset_index()
        # Convert values 
        df["Time_in_s"] = df["Time"].apply(lambda x: get_time_in_s(x))
        # Locust has zero point
        df["Time_in_s"] = df["Time_in_s"] - start_point
        df["Time_datetime"] = df["Time"].apply(lambda x: get_time_date(x))
        # cpu is in nanosecond so dive by 1000 is microsecond divide by 100 is milicore
        df["CPU"] = (df["CPU"] / 1000) / 1000
        
        plot_cpu_per_pod(df, pod, color=colors[i % len(colors)])
        
    plt.show()

    for i, pod in enumerate(os.listdir(data_directory)):
        if pod.startswith("locust_data") or pod.startswith("bf") or \
            pod.startswith("locust_stat") or pod.startswith("vms_stats.csv") \
            or pod.startswith("epi-bf"):
            continue
        
        f_name = f"{data_directory}/" + pod
        print("f_name: ", f_name)
        
        df = pd.read_csv(f_name, delimiter=",")
        df = df.iloc[5:]
        df = df.reset_index()
        # Convert values 
        df["Time_in_s"] = df["Time"].apply(lambda x: get_time_in_s(x))
        # Locust has zero point
        df["Time_in_s"] = df["Time_in_s"] - start_point
        df["Time_datetime"] = df["Time"].apply(lambda x: get_time_date(x))
        # cpu is in nanosecond so dive by 1000 is microsecond divide by 100 is milicore
        df["CPU"] = (df["CPU"] / 1000) / 1000
        
        plot_cpu_per_pod(df, pod, )
#         plot_memory(df)

#         plt.ylim(0, 20)
        
        plt.show()
    
    plot_request_per_second(df_locust)
    plot_users_per_second(df_locust)
#     plot_response_times_per_second(df_locust)

    exit(1)
# Out:
# Directory: TEST_NO_4_20210618200735
# data directory: ../hpa_test_data/TEST_NO_4_20210618200735
# epi-bf-74d5f4df87-86vqn.txt
# f_name:  ../hpa_test_data/TEST_NO_4_20210618200735/epi-bf-74d5f4df87-86vqn.txt
# f_name:  ../hpa_test_data/TEST_NO_4_20210618200735/epi-server-559c57ccdd-w7hv9.txt
# f_name:  ../hpa_test_data/TEST_NO_4_20210618200735/epi-proxy-5447cc89bf-4glvg.txt
# Directory: TEST_NO_14_20210618203759
# data directory: ../hpa_test_data/TEST_NO_14_20210618203759
# epi-bf-75bc7ff569-jb9b2.txt
# f_name:  ../hpa_test_data/TEST_NO_14_20210618203759/epi-bf-75bc7ff569-jb9b2.txt
# f_name:  ../hpa_test_data/TEST_NO_14_20210618203759/epi-server-559c57ccdd-q9vh4.txt
# f_name:  ../hpa_test_data/TEST_NO_14_20210618203759/epi-proxy-5447cc89bf-5rj9b.txt
# Directory: TEST_NO_8_20210618201950
# data directory: ../hpa_test_data/TEST_NO_8_20210618201950
# epi-bf-74d5f4df87-zcc2t.txt
# f_name:  ../hpa_test_data/TEST_NO_8_20210618201950/epi-bf-74d5f4df87-zcc2t.txt
# f_name:  ../hpa_test_data/TEST_NO_8_20210618201950/epi-proxy-5447cc89bf-td7x5.txt
# f_name:  ../hpa_test_data/TEST_NO_8_20210618201950/epi-server-559c57ccdd-5ck4d.txt
# Directory: TEST_NO_15_20210618204053
# data directory: ../hpa_test_data/TEST_NO_15_20210618204053
# epi-bf-65b758fc7b-fb57v.txt
# f_name:  ../hpa_test_data/TEST_NO_15_20210618204053/epi-bf-65b758fc7b-fb57v.txt
# f_name:  ../hpa_test_data/TEST_NO_15_20210618204053/epi-server-559c57ccdd-hz8w4.txt
# f_name:  ../hpa_test_data/TEST_NO_15_20210618204053/epi-proxy-5447cc89bf-qzdt5.txt
# Directory: TEST_NO_5_20210618201031
# data directory: ../hpa_test_data/TEST_NO_5_20210618201031
# epi-bf-7fccdf5f46-v9vkj.txt
# f_name:  ../hpa_test_data/TEST_NO_5_20210618201031/epi-bf-7fccdf5f46-v9vkj.txt
# f_name:  ../hpa_test_data/TEST_NO_5_20210618201031/epi-server-559c57ccdd-7q6sm.txt
# f_name:  ../hpa_test_data/TEST_NO_5_20210618201031/epi-proxy-5447cc89bf-4vkcc.txt
# Directory: TEST_NO_12_20210618203208
# data directory: ../hpa_test_data/TEST_NO_12_20210618203208
# epi-bf-74d5f4df87-prbnw.txt
# f_name:  ../hpa_test_data/TEST_NO_12_20210618203208/epi-bf-74d5f4df87-prbnw.txt
# f_name:  ../hpa_test_data/TEST_NO_12_20210618203208/epi-proxy-5447cc89bf-s4vq6.txt
# f_name:  ../hpa_test_data/TEST_NO_12_20210618203208/epi-server-559c57ccdd-ftmll.txt
# Directory: TEST_NO_2_20210618200138
# data directory: ../hpa_test_data/TEST_NO_2_20210618200138
# epi-bf-75bc7ff569-gz5rl.txt
# f_name:  ../hpa_test_data/TEST_NO_2_20210618200138/epi-bf-75bc7ff569-gz5rl.txt
# f_name:  ../hpa_test_data/TEST_NO_2_20210618200138/epi-proxy-5447cc89bf-8c262.txt
# f_name:  ../hpa_test_data/TEST_NO_2_20210618200138/epi-server-559c57ccdd-wpcnl.txt
# Directory: TEST_NO_16_20210618204412
# data directory: ../hpa_test_data/TEST_NO_16_20210618204412
# epi-bf-74d5f4df87-r26dr.txt
# f_name:  ../hpa_test_data/TEST_NO_16_20210618204412/epi-bf-74d5f4df87-r26dr.txt
# f_name:  ../hpa_test_data/TEST_NO_16_20210618204412/epi-server-559c57ccdd-xwclm.txt
# f_name:  ../hpa_test_data/TEST_NO_16_20210618204412/epi-proxy-5447cc89bf-657tg.txt
# Directory: TEST_NO_9_20210618202250
# data directory: ../hpa_test_data/TEST_NO_9_20210618202250
# epi-bf-7fccdf5f46-m6fmk.txt
# f_name:  ../hpa_test_data/TEST_NO_9_20210618202250/epi-bf-7fccdf5f46-m6fmk.txt
# f_name:  ../hpa_test_data/TEST_NO_9_20210618202250/epi-server-559c57ccdd-6mhc6.txt
# f_name:  ../hpa_test_data/TEST_NO_9_20210618202250/epi-proxy-5447cc89bf-vjsd8.txt
# Directory: TEST_NO_3_20210618200421
# data directory: ../hpa_test_data/TEST_NO_3_20210618200421
# epi-bf-65b758fc7b-9vwcz.txt
# f_name:  ../hpa_test_data/TEST_NO_3_20210618200421/epi-bf-65b758fc7b-9vwcz.txt
# f_name:  ../hpa_test_data/TEST_NO_3_20210618200421/epi-server-559c57ccdd-6wnp8.txt
# f_name:  ../hpa_test_data/TEST_NO_3_20210618200421/epi-proxy-5447cc89bf-lpwvx.txt
# Directory: TEST_NO_11_20210618202842
# data directory: ../hpa_test_data/TEST_NO_11_20210618202842
# epi-bf-65b758fc7b-hjq5d.txt
# f_name:  ../hpa_test_data/TEST_NO_11_20210618202842/epi-bf-65b758fc7b-hjq5d.txt
# f_name:  ../hpa_test_data/TEST_NO_11_20210618202842/epi-proxy-5447cc89bf-dwgfh.txt
# f_name:  ../hpa_test_data/TEST_NO_11_20210618202842/epi-server-559c57ccdd-lc78q.txt
# Directory: TEST_NO_1_20210618195826
# data directory: ../hpa_test_data/TEST_NO_1_20210618195826
# epi-bf-7fccdf5f46-4rdc6.txt
# f_name:  ../hpa_test_data/TEST_NO_1_20210618195826/epi-bf-7fccdf5f46-4rdc6.txt
# epi-bf-7fccdf5f46-gvknk.txt
# f_name:  ../hpa_test_data/TEST_NO_1_20210618195826/epi-bf-7fccdf5f46-gvknk.txt
# epi-bf-7fccdf5f46-smphb.txt
# f_name:  ../hpa_test_data/TEST_NO_1_20210618195826/epi-bf-7fccdf5f46-smphb.txt
# epi-bf-7fccdf5f46-zgz5x.txt
# f_name:  ../hpa_test_data/TEST_NO_1_20210618195826/epi-bf-7fccdf5f46-zgz5x.txt
# epi-bf-7fccdf5f46-tphrr.txt
# f_name:  ../hpa_test_data/TEST_NO_1_20210618195826/epi-bf-7fccdf5f46-tphrr.txt
# f_name:  ../hpa_test_data/TEST_NO_1_20210618195826/epi-proxy-5447cc89bf-455bd.txt
# f_name:  ../hpa_test_data/TEST_NO_1_20210618195826/epi-server-559c57ccdd-khv4c.txt
# Directory: TEST_NO_7_20210618201652
# data directory: ../hpa_test_data/TEST_NO_7_20210618201652
# epi-bf-65b758fc7b-7r48q.txt
# f_name:  ../hpa_test_data/TEST_NO_7_20210618201652/epi-bf-65b758fc7b-7r48q.txt
# f_name:  ../hpa_test_data/TEST_NO_7_20210618201652/epi-proxy-5447cc89bf-mt8vz.txt
# f_name:  ../hpa_test_data/TEST_NO_7_20210618201652/epi-server-559c57ccdd-4bssn.txt
# Directory: TEST_NO_10_20210618202550
# data directory: ../hpa_test_data/TEST_NO_10_20210618202550
# epi-bf-75bc7ff569-bqrtj.txt
# f_name:  ../hpa_test_data/TEST_NO_10_20210618202550/epi-bf-75bc7ff569-bqrtj.txt
# f_name:  ../hpa_test_data/TEST_NO_10_20210618202550/epi-proxy-5447cc89bf-srwcx.txt
# f_name:  ../hpa_test_data/TEST_NO_10_20210618202550/epi-server-559c57ccdd-k8srl.txt
# Directory: TEST_NO_6_20210618201343
# data directory: ../hpa_test_data/TEST_NO_6_20210618201343
# epi-bf-75bc7ff569-wx9z5.txt
# f_name:  ../hpa_test_data/TEST_NO_6_20210618201343/epi-bf-75bc7ff569-wx9z5.txt
# f_name:  ../hpa_test_data/TEST_NO_6_20210618201343/epi-proxy-5447cc89bf-hs7t2.txt
# f_name:  ../hpa_test_data/TEST_NO_6_20210618201343/epi-server-559c57ccdd-7xzb6.txt
# Directory: TEST_NO_13_20210618203500
# data directory: ../hpa_test_data/TEST_NO_13_20210618203500
# epi-bf-7fccdf5f46-gdrhs.txt
# f_name:  ../hpa_test_data/TEST_NO_13_20210618203500/epi-bf-7fccdf5f46-gdrhs.txt
# f_name:  ../hpa_test_data/TEST_NO_13_20210618203500/epi-proxy-5447cc89bf-9ndhb.txt
# f_name:  ../hpa_test_data/TEST_NO_13_20210618203500/epi-server-559c57ccdd-psprt.txt
